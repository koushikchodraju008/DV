# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("100 Sales Records.csv")
print("📌 First 5 rows of the dataset:")
print(df.head())
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
print("\n📌 Missing Values in Each Column:")
print(df.isnull().sum())
print("\n📌 Data Types of Columns:")
print(df.dtypes)
# Out:
#      <input type="file" id="files-b8f33245-81f2-4be5-92b0-270cf3d98bf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8f33245-81f2-4be5-92b0-270cf3d98bf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
sns.set(style="whitegrid")
uploaded = files.upload()
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)
print(" First 5 rows of the dataset:")
print(df.head())
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')
print("\n Missing Values in Each Column:")
print(df.isnull().sum())
print("\n Data Types of Columns:")
print(df.dtypes)
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Item Type', order=df['Item Type'].value_counts().index)
plt.title("Bar Chart - Frequency of Item Types")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
sales_channel_counts = df['Sales Channel'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(sales_channel_counts, labels=sales_channel_counts.index, autopct='%1.1f%%',
startangle=140)
plt.title("Pie Chart - Sales Channel Distribution")
plt.axis('equal')
plt.show()
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Unit Price', y='Units Sold', hue='Region')
plt.title("Scatterplot - Unit Price vs Units Sold")
plt.show()
df_sorted = df.sort_values('Order Date')
plt.figure(figsize=(12,6))
sns.lineplot(data=df_sorted, x='Order Date', y='Total Revenue')
plt.title("Line Plot - Total Revenue Over Time")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.figure(figsize=(10,6))
sns.stripplot(data=df, x='Region', y='Total Profit', jitter=True)
plt.title("Strip Plot - Total Profit by Region")
plt.xticks(rotation=45)
plt.show()
plt.figure(figsize=(12,6))
sns.swarmplot(data=df, x='Item Type', y='Unit Cost')
plt.title("Swarm Plot - Unit Cost by Item Type")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.figure(figsize=(8,6))
sns.histplot(df['Units Sold'], bins=20)
plt.title("Histogram - Units Sold")
plt.show()
plt.figure(figsize=(8,6))
sns.kdeplot(df['Total Profit'], fill=True)
plt.title("Density Plot - Total Profit")
plt.show()
plt.figure(figsize=(8,6))
sns.rugplot(df['Unit Price'])
plt.title("Rug Plot - Unit Price")
plt.show()
# Out:
#      <input type="file" id="files-636f6414-348a-41ca-82c9-0ac46cb807d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-636f6414-348a-41ca-82c9-0ac46cb807d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
sns.set(style="whitegrid")
uploaded = files.upload()
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)
print(" First 5 rows of the dataset:")
print(df.head())
#df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
#df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')
print("\n Missing Values in Each Column:")
print(df.isnull().sum())
print("\n Data Types of Columns:")
print(df.dtypes)
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Condition', order=df['Condition'].value_counts().index)
plt.title("Bar Chart - Frequency of Condition")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
sales_channel_counts = df['Gender'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(sales_channel_counts, labels=sales_channel_counts.index, autopct='%1.1f%%',
startangle=140)
plt.title("Pie Chart - Gender Distribution")
plt.axis('equal')
plt.show()
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Cost', y='Length_of_Stay', hue='Readmission')
plt.title("Scatterplot - Cost vs Length of Stay")
plt.show()
#df_sorted = df.sort_values('Order Date')
#plt.figure(figsize=(12,6))
#sns.lineplot(data=df_sorted, x='Order Date', y='Total Revenue')
#plt.title("Line Plot - Total Revenue Over Time")
#plt.xticks(rotation=45)
#plt.tight_layout()
#plt.show()
plt.figure(figsize=(10,6))
sns.stripplot(data=df, x='Outcome', y='Satisfaction', jitter=True)
plt.title("Strip Plot - Satisfaction by Outcome")
plt.xticks(rotation=45)
plt.show()
plt.figure(figsize=(12,6))
sns.swarmplot(data=df, x='Condition', y='Cost')
plt.title("Swarm Plot - Cost by Condition")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.figure(figsize=(8,6))
sns.histplot(df['Length_of_Stay'], bins=20)
plt.title("Histogram - Length of Stay")
plt.show()
plt.figure(figsize=(8,6))
sns.kdeplot(df['Satisfaction'], fill=True)
plt.title("Density Plot - Satisfaction")
plt.show()
plt.figure(figsize=(8,6))
sns.rugplot(df['Cost'])
plt.title("Rug Plot - Cost")
plt.show()
# Out:
#      <input type="file" id="files-46d06edd-e434-4537-93d6-3d209a9a682b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46d06edd-e434-4537-93d6-3d209a9a682b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
